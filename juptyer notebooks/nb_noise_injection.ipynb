# %%
import numpy as np
from scipy.stats import nbinom
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
import sys
import pandas as pd

estimated_data = pd.read_csv('../datasets/particle_observation.csv').to_numpy()
estimated_data = np.delete(estimated_data,0,1)

plt.yscale('log')
plt.plot(estimated_data)

output = np.copy(timeseries)

r = 40

r=np.ceil(r) 

for i in range(len(timeseries)):    
    output[i] = nbinom.rvs(n=r, p=r/(r+timeseries[i]), size=1)
# Out:
# [<matplotlib.lines.Line2D at 0x16e1d1010>,
#  <matplotlib.lines.Line2D at 0x15fb6db50>,
#  <matplotlib.lines.Line2D at 0x16e1d2050>,
#  <matplotlib.lines.Line2D at 0x16e1ea7d0>,
#  <matplotlib.lines.Line2D at 0x16e1faad0>,
#  <matplotlib.lines.Line2D at 0x16e1faf50>,
#  <matplotlib.lines.Line2D at 0x16e1fadd0>,
#  <matplotlib.lines.Line2D at 0x15f6a1d90>,
#  <matplotlib.lines.Line2D at 0x16e1fbcd0>,
#  <matplotlib.lines.Line2D at 0x16e1c2890>,
#  <matplotlib.lines.Line2D at 0x16e20b650>,
#  <matplotlib.lines.Line2D at 0x16e20a090>,
#  <matplotlib.lines.Line2D at 0x16e208ad0>,
#  <matplotlib.lines.Line2D at 0x16e208310>,
#  <matplotlib.lines.Line2D at 0x15f505990>,
#  <matplotlib.lines.Line2D at 0x16e209090>,
#  <matplotlib.lines.Line2D at 0x16e209650>,
#  <matplotlib.lines.Line2D at 0x16e14b4d0>,
#  <matplotlib.lines.Line2D at 0x16e20a650>,
#  <matplotlib.lines.Line2D at 0x15f627550>,
#  <matplotlib.lines.Line2D at 0x16e20aad0>,
#  <matplotlib.lines.Line2D at 0x16e20b290>,
#  <matplotlib.lines.Line2D at 0x16e20b750>]
